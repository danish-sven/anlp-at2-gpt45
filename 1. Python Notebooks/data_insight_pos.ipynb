# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
jp=pd.read_csv('../3. Cleaned Data/MDNtoEN_clean_SS_POS.csv')
md=pd.read_csv('../3. Cleaned Data/MDNtoEN_clean_SS_POS.csv')

# %%
md.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75721 entries, 0 to 75720
# Data columns (total 32 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            75721 non-null  int64
#  1   original              75721 non-null  object
#  2   corrected             75721 non-null  object
#  3   o_pos_tags            75721 non-null  object
#  4   o_num_verbs           75721 non-null  int64
#  5   o_num_nouns           75721 non-null  int64
#  6   o_num_adjs            75721 non-null  int64
#  7   o_num_adv             75721 non-null  int64
#  8   o_num_pronoun         75721 non-null  int64
#  9   o_num_preposition     75721 non-null  int64
#  10  o_num_conjunction     75721 non-null  int64
#  11  o_num_article         75721 non-null  int64
#  12  o_num_modal           75721 non-null  int64
#  13  c_pos_tags            75721 non-null  object
#  14  c_num_verbs           75721 non-null  int64
# ...

# %%
jp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75721 entries, 0 to 75720
# Data columns (total 32 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            75721 non-null  int64
#  1   original              75721 non-null  object
#  2   corrected             75721 non-null  object
#  3   o_pos_tags            75721 non-null  object
#  4   o_num_verbs           75721 non-null  int64
#  5   o_num_nouns           75721 non-null  int64
#  6   o_num_adjs            75721 non-null  int64
#  7   o_num_adv             75721 non-null  int64
#  8   o_num_pronoun         75721 non-null  int64
#  9   o_num_preposition     75721 non-null  int64
#  10  o_num_conjunction     75721 non-null  int64
#  11  o_num_article         75721 non-null  int64
#  12  o_num_modal           75721 non-null  int64
#  13  c_pos_tags            75721 non-null  object
#  14  c_num_verbs           75721 non-null  int64
# ...

# %% [markdown]
# ## Japanese Word count difference by POS

# %%
# visualise the histogram for num_verbs_diff
sns.histplot(data=jp,x='num_verbs_diff',color='#53aff4',edgecolor='grey')
# Out:
# <Axes: xlabel='num_verbs_diff', ylabel='Count'>

# %%
# visualise the histogram for num_nouns_diff
sns.histplot(data=jp,x='num_nouns_diff',color='#53aff4',edgecolor='grey')
# Out:
# <Axes: xlabel='num_nouns_diff', ylabel='Count'>

# %%
# visualise the histogram for num_adjs_diff
sns.histplot(data=jp,x='num_adjs_diff',color='#53aff4',edgecolor='grey')
# Out:
# <Axes: xlabel='num_adjs_diff', ylabel='Count'>

# %%
# visualise the histogram for num_adv_diff
sns.histplot(data=jp,x='num_adv_diff',color='#53aff4',edgecolor='grey')
# Out:
# <Axes: xlabel='num_adv_diff', ylabel='Count'>

# %%
# visualise the histogram for num_pronoun_diff
sns.histplot(data=md,x='num_pronoun_diff',color='#53aff4',edgecolor='grey')
# Out:
# <Axes: xlabel='num_pronoun_diff', ylabel='Count'>

# %%
# visualise the histogram for num_preposition_diff
sns.histplot(data=jp,x='num_preposition_diff',color='#53aff4',edgecolor='grey')
# Out:
# <Axes: xlabel='num_preposition_diff', ylabel='Count'>

# %%
# visualise the histogram for num_conjunction_diff
sns.histplot(data=jp,x='num_conjunction_diff',color='#53aff4',edgecolor='grey')
# Out:
# <Axes: xlabel='num_conjunction_diff', ylabel='Count'>

# %%
# visualise the histogram for num_article_diff
sns.histplot(data=jp,x='num_article_diff',color='#53aff4',edgecolor='grey')
# Out:
# <Axes: xlabel='num_article_diff', ylabel='Count'>

# %%
# visualise the histogram for num_modal_diff
sns.histplot(data=jp,x='num_modal_diff',color='#53aff4',edgecolor='grey')
# Out:
# <Axes: xlabel='num_modal_diff', ylabel='Count'>

# %% [markdown]
# ## Mandarin Word count difference by POS

# %%
# visualise the histogram for num_verbs_diff
sns.histplot(data=md,x='num_verbs_diff',color='#53aff4',edgecolor='grey')
# Out:
# <Axes: xlabel='num_verbs_diff', ylabel='Count'>

# %%
# visualise the histogram for num_nouns_diff
sns.histplot(data=md,x='num_nouns_diff',color='#53aff4',edgecolor='grey')
# Out:
# <Axes: xlabel='num_nouns_diff', ylabel='Count'>

# %%
# visualise the histogram for num_adjs_diff
sns.histplot(data=md,x='num_adjs_diff',color='#53aff4',edgecolor='grey')
# Out:
# <Axes: xlabel='num_adjs_diff', ylabel='Count'>

# %%
# visualise the histogram for num_adv_diff
sns.histplot(data=md,x='num_adv_diff',color='#53aff4',edgecolor='grey')
# Out:
# <Axes: xlabel='num_adv_diff', ylabel='Count'>

# %%
# visualise the histogram for num_pronoun_diff
sns.histplot(data=md,x='num_pronoun_diff',color='#53aff4',edgecolor='grey')
# Out:
# <Axes: xlabel='num_pronoun_diff', ylabel='Count'>

# %%
# visualise the histogram for num_preposition_diff
sns.histplot(data=md,x='num_preposition_diff',color='#53aff4',edgecolor='grey')
# Out:
# <Axes: xlabel='num_preposition_diff', ylabel='Count'>

# %%
# visualise the histogram for num_conjunction_diff
sns.histplot(data=md,x='num_conjunction_diff',color='#53aff4',edgecolor='grey')
# Out:
# <Axes: xlabel='num_conjunction_diff', ylabel='Count'>

# %%
# visualise the histogram for num_article_diff
sns.histplot(data=md,x='num_article_diff',color='#53aff4',edgecolor='grey')
# Out:
# <Axes: xlabel='num_article_diff', ylabel='Count'>

# %%
# visualise the histogram for num_modal_diff
sns.histplot(data=md,x='num_modal_diff',color='#53aff4',edgecolor='grey')
# Out:
# <Axes: xlabel='num_modal_diff', ylabel='Count'>
